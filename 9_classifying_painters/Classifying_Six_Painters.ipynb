# %% [markdown]
# # Import

# %%
from tensorflow import keras
from keras import layers
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.utils import image_dataset_from_directory

# %% [markdown]
# # Data importeren

# %% [markdown]
# Importeren van de data uit drive,
# vul de authorization code in die verkregen wordt via de link of er wordt al direct een scherm opgebracht waar je kan inloggen.

# %%
from google.colab import drive
drive.mount('/gdrive')
# !ln -s "/gdrive/My Drive/Schilderijen-Classificeren_Arthur-Huys/datasets" "/content/datasets"
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# ln: failed to create symbolic link '/content/datasets/datasets': File exists

# %%
import shutil
shutil.unpack_archive('datasets/Picasso_Rubens_VanGogh_Mondriaan_rembrandt_AI_1000_20_20.zip','.','zip')

# %% [markdown]
# # creëren datasets

# %% [markdown]
# Bij het creëren van deze datasets moet de class_mode verandert naar categorical omdat we nu met multi class data werken (3 verschillende labels).

# %%
train_dataset = image_dataset_from_directory(
    "Picasso_Rubens_VanGogh_Mondriaan_rembrandt_AI_1000_20_20/train",
    image_size=(224, 224),
    batch_size=32,
    label_mode="categorical")

validation_dataset = image_dataset_from_directory(
    "Picasso_Rubens_VanGogh_Mondriaan_rembrandt_AI_1000_20_20/validation",
    image_size=(224, 224),
    batch_size=32,
    label_mode="categorical")

test_dataset = image_dataset_from_directory(
    "Picasso_Rubens_VanGogh_Mondriaan_rembrandt_AI_1000_20_20/test",
    image_size=(224, 224),
    batch_size=32,
    label_mode="categorical")
# Out:
# Found 6000 files belonging to 6 classes.
# Found 120 files belonging to 6 classes.
# Found 120 files belonging to 6 classes.

# %% [markdown]
# # Building model

# %%
base_model = keras.applications.ResNet50(
    include_top=False, 
    weights="imagenet",
    classes=6,
    classifier_activation="softmax")

base_model.trainable = True
for layer in base_model.layers[:-12]:
  layer.trainable = False

# %%
data_augmentation = keras.Sequential(
    [layers.RandomTranslation(height_factor=0.2, width_factor=0.2),
     layers.RandomContrast(0.5,1.5)])

# %%
inputs = keras.Input(shape=(224, 224, 3))
x = data_augmentation(inputs)
x = keras.applications.resnet50.preprocess_input(x)
x = base_model(x)
x = layers.Flatten()(x)
x = layers.Dense(256)(x)
x = layers.BatchNormalization()(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(6, activation="softmax")(x)
model = keras.Model(inputs, outputs)

# %%
model.compile(loss="categorical_crossentropy",
              optimizer="sgd",
              metrics=["accuracy"])

# %% [markdown]
# # Training model

# %%
callbacks = [keras.callbacks.ModelCheckpoint(
    filepath="feature_extraction.keras",
    save_best_only=True,
    monitor="val_loss")]

# %%
history = model.fit(
    train_dataset,
    epochs=30,
    validation_data=validation_dataset,
    callbacks=callbacks)
# Out:
# Epoch 1/30
# 188/188 [==============================] - ETA: 0s - loss: 0.4594 - accuracy: 0.8688
# /usr/local/lib/python3.7/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# 188/188 [==============================] - 58s 283ms/step - loss: 0.4594 - accuracy: 0.8688 - val_loss: 0.0483 - val_accuracy: 0.9917
# Epoch 2/30
# 188/188 [==============================] - 52s 273ms/step - loss: 0.1580 - accuracy: 0.9465 - val_loss: 0.0752 - val_accuracy: 0.9833
# Epoch 3/30
# 188/188 [==============================] - 52s 273ms/step - loss: 0.1085 - accuracy: 0.9632 - val_loss: 0.1090 - val_accuracy: 0.9583
# Epoch 4/30
# 188/188 [==============================] - 52s 273ms/step - loss: 0.0732 - accuracy: 0.9755 - val_loss: 0.0938 - val_accuracy: 0.9667
# Epoch 5/30
# 188/188 [==============================] - 52s 271ms/step - loss: 0.0623 - accuracy: 0.9780 - val_loss: 0.1639 - val_accuracy: 0.9583
# Epoch 6/30
# 188/188 [==============================] - 53s 274ms/step - loss: 0.0453 - accuracy: 0.9850 - val_loss: 0.1249 - val_accuracy: 0.9667
# Epoch 7/30
# 188/188 [==============================] - 52s 272ms/step - loss: 0.0328 - accuracy: 0.9895 - val_loss: 0.0906 - val_accuracy: 0.9667
# Epoch 8/30
# 188/188 [==============================] - 53s 274ms/step - loss: 0.0358 - accuracy: 0.9897 - val_loss: 0.1197 - val_accuracy: 0.9667
# Epoch 9/30
# 188/188 [==============================] - 52s 272ms/step - loss: 0.0313 - accuracy: 0.9885 - val_loss: 0.0887 - val_accuracy: 0.9667
# Epoch 10/30
# 188/188 [==============================] - 52s 271ms/step - loss: 0.0298 - accuracy: 0.9907 - val_loss: 0.1223 - val_accuracy: 0.9583
# Epoch 11/30
# 188/188 [==============================] - 52s 272ms/step - loss: 0.0224 - accuracy: 0.9925 - val_loss: 0.1193 - val_accuracy: 0.9750
# Epoch 12/30
# 188/188 [==============================] - 52s 271ms/step - loss: 0.0222 - accuracy: 0.9930 - val_loss: 0.1273 - val_accuracy: 0.9667
# Epoch 13/30
# 188/188 [==============================] - 52s 272ms/step - loss: 0.0192 - accuracy: 0.9940 - val_loss: 0.1134 - val_accuracy: 0.9667
# Epoch 14/30
# 188/188 [==============================] - 52s 271ms/step - loss: 0.0175 - accuracy: 0.9947 - val_loss: 0.1312 - val_accuracy: 0.9667
# Epoch 15/30
# 188/188 [==============================] - 52s 272ms/step - loss: 0.0151 - accuracy: 0.9953 - val_loss: 0.1128 - val_accuracy: 0.9667
# Epoch 16/30
# 188/188 [==============================] - 52s 272ms/step - loss: 0.0132 - accuracy: 0.9957 - val_loss: 0.1063 - val_accuracy: 0.9667
# Epoch 17/30
# 188/188 [==============================] - 52s 273ms/step - loss: 0.0153 - accuracy: 0.9958 - val_loss: 0.1124 - val_accuracy: 0.9583
# Epoch 18/30
# 188/188 [==============================] - 52s 272ms/step - loss: 0.0162 - accuracy: 0.9950 - val_loss: 0.1279 - val_accuracy: 0.9583
# Epoch 19/30
# 188/188 [==============================] - 52s 271ms/step - loss: 0.0158 - accuracy: 0.9952 - val_loss: 0.0925 - val_accuracy: 0.9750
# Epoch 20/30
# 188/188 [==============================] - 52s 270ms/step - loss: 0.0096 - accuracy: 0.9973 - val_loss: 0.0792 - val_accuracy: 0.9750
# Epoch 21/30
# 188/188 [==============================] - 52s 273ms/step - loss: 0.0111 - accuracy: 0.9968 - val_loss: 0.0858 - val_accuracy: 0.9667
# Epoch 22/30
# 188/188 [==============================] - 52s 273ms/step - loss: 0.0095 - accuracy: 0.9975 - val_loss: 0.1048 - val_accuracy: 0.9667
# Epoch 23/30
# 188/188 [==============================] - 52s 272ms/step - loss: 0.0107 - accuracy: 0.9962 - val_loss: 0.0909 - val_accuracy: 0.9667
# Epoch 24/30
# 188/188 [==============================] - 52s 271ms/step - loss: 0.0072 - accuracy: 0.9977 - val_loss: 0.1008 - val_accuracy: 0.9667
# Epoch 25/30
# 188/188 [==============================] - 52s 272ms/step - loss: 0.0113 - accuracy: 0.9960 - val_loss: 0.1195 - val_accuracy: 0.9667
# Epoch 26/30
# 188/188 [==============================] - 52s 273ms/step - loss: 0.0064 - accuracy: 0.9982 - val_loss: 0.0901 - val_accuracy: 0.9750
# Epoch 27/30
# 188/188 [==============================] - 52s 271ms/step - loss: 0.0089 - accuracy: 0.9975 - val_loss: 0.0727 - val_accuracy: 0.9667
# Epoch 28/30
# 188/188 [==============================] - 52s 272ms/step - loss: 0.0094 - accuracy: 0.9972 - val_loss: 0.0875 - val_accuracy: 0.9750
# Epoch 29/30
# 188/188 [==============================] - 52s 272ms/step - loss: 0.0073 - accuracy: 0.9980 - val_loss: 0.1068 - val_accuracy: 0.9667
# Epoch 30/30
# 188/188 [==============================] - 52s 272ms/step - loss: 0.0065 - accuracy: 0.9988 - val_loss: 0.0977 - val_accuracy: 0.9667

# %%
acc = history.history["accuracy"]
val_acc = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(acc) + 1)
plt.plot(epochs, acc, "bo", label="Training accuracy")
plt.plot(epochs, val_acc, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.legend()
plt.figure()
plt.plot(epochs, loss, "bo", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()

# %% [markdown]
# # Testing

# %% [markdown]
# Hier kunnen we weer zien dat de validation accuracy ongeveer gelijk blijf na de 40ste epoch.

# %%
test_model = keras.models.load_model("feature_extraction.keras")
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 4/4 [==============================] - 2s 206ms/step - loss: 0.1776 - accuracy: 0.9333
# Test accuracy: 0.933

# %%
test_model.save("model_six_painters.h5")
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)

# %%
# !ln -s "/gdrive/My Drive/Schilderijen-Classificeren_Arthur-Huys/models" "/content/models"
# Out:
# ln: failed to create symbolic link '/content/models/models': File exists
